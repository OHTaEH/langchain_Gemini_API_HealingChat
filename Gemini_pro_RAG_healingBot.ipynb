# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Markdown

import os
os.environ["GOOGLE_API_KEY"] = "GOOGLE_API_KEY"

# %%
# %pip install -U --quiet langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 13.2 MB/s eta 0:00:00

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-pro")
result = llm.invoke("마음이 힘들때 어떻게 해야 해?")
Markdown(result.content)
# Out:
# **감정 인정 및 표현**
#
# * 자신이 느끼는 감정을 인정하고 받아들입니다.
# * 일기를 쓰거나, 친구나 가족에게 이야기하거나, 상담사를 만나 감정을 표현합니다.
# * 억압하지 말고 건강한 방법으로 감정을 처리합니다.
#
# **자기 관리 실천**
#
# * 충분한 수면을 취합니다.
# * 건강한 식단을 섭취합니다.
# * 규칙적으로 운동합니다.
# * 마음챙김이나 명상을 연습합니다.
#
# **지원 체계 구축**
#
# * 친구, 가족, 상담사와 같은 지지 체계를 구축합니다.
# * 이들이 자신의 감정을 이해하고 지원해 준다는 것을 알 수 있습니다.
# * 혼자서 모든 것을 해결하려고 하지 않습니다.
#
# **긍정적 사고 연습**
#
# * 부정적인 생각에 끌리지 않도록 노력합니다.
# * 긍정적인 측면에 초점을 맞춥니다.
# * 감사일기를 쓰거나, 행복한 일에 집중합니다.
#
# **문제 해결**
#
# * 마음이 힘든 상황을 파악합니다.
# * 해결책을 찾고, 필요한 조치를 취합니다.
# * 문제를 극복하기 위해 현실적인 목표를 설정합니다.
#
# **전문적인 도움 구하기**
#
# * 감정이 너무 압도적이거나 대처할 수 없을 때 전문적인 도움을 구합니다.
# * 상담사나 치료사는 마음의 어려움을 극복하는 데 도움을 줄 수 있습니다.
#
# **기타 유용한 팁**
#
# * 자연 속에서 시간을 보냅니다.
# * 창의적인 활동에 참여합니다.
# * 취미를 즐깁니다.
# * 소셜 미디어를 제한합니다.
# * 자기 연민을 연습합니다.
# * 회복에는 시간이 걸린다는 것을 기억합니다.

# %%
# %pip install -U --quiet langchain tiktoken pypdf sentence_transformers chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.0/817.0 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 19.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 41.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 73.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 44.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 48.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 51.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 33.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 45.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.8 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
# from langchain.chains import RetrievalQA
# from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("/content/drive/MyDrive/psy_text.pdf")
pages = loader.load_and_split()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
texts = text_splitter.split_documents(pages)

from langchain.embeddings import HuggingFaceEmbeddings

model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': 'cuda'}
encode_kwargs = {'normalize_embeddings': True}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

docsearch = Chroma.from_documents(texts, hf)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.46k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
 retriever = docsearch.as_retriever(
                                    search_type="mmr",
                                    search_kwargs={'k':3, 'fetch_k': 10})
 retriever.get_relevant_documents("우울할때 해결 방법을 알려줘")
# Out:
# [Document(page_content='편에 최악의  경우를  쓰자. 최악을  받아들일  때, 걱정이  눈 녹듯이  사라진다 . "피할 수 없 \n으면 받아들여라 ." \n \n셋째, "그만!"을 외치자 . 걱정할수록  불안이  커진다 . "그만!"을 외치고 , 주변에  초점을  \n맞추자 . 벽에 걸린 시계나  천장에  있는 형광등을  물끄러미  바라보자 . "그만!"을 외치고 ,', metadata={'page': 2, 'source': '/content/drive/MyDrive/psy_text.pdf'}),
#  Document(page_content='화를 선택하자 . 분노가  치솟는  순간, 즉각 자리를  피하자 . 한적한  곳을 걸으면서 , 세 가 \n지에 집중해  보자. 1 왜 화가 나는가 ? 2 무엇을  위해 화를 내는가 ? 3 다른 효과적인  \n방법은  없는가 ? 분통이  터지는  순간, 하루만  모든 결정을  보류하자 . 떠오르는  모든 생각 \n을 종이 한 장에 써 보자.', metadata={'page': 6, 'source': '/content/drive/MyDrive/psy_text.pdf'}),
#  Document(page_content='하고 있다. 자신의  감정과  다른 감정을  요구받고  있다. 감정의  억압과  부조화는  큰 스트 \n레스로  작용한다 . 스트레스  반응은  몸과 마음에  나타나는  증상이다 . 스트레스는  우리의  \n몸을 망가뜨리고  마음도  엉망으로  만든다 . 사회적인  관계를  무너뜨리고  영적인  혼돈상  \n태로 빠뜨린다 . \n스트레스  관리는  현대인의  화두다 . 과거에는  자기계발이  있었다 . 일깨우고  개발할  게 \n많던 시절이다 . 언젠가부터  자기관리란  말이 떠돌았다 . 스스로  책임져야  한다는  것이 \n상식화된  것이다 . 이제 스트레스  관리가  대세다 . 현대인은  엄청난  스트레스  가운데  살 \n아간다 . 스트레스는  개인의  잠재능력을  제한한다 . 스트레스  관리가  일상이  돼야 한다. \n우리는  매일 스트레스가  어디로부터  왔는지 , 어디를  망가뜨렸는지  점검해야  한다. 정확 \n한 평가와  효과적인  접근이  필요하다 .', metadata={'page': 4, 'source': '/content/drive/MyDrive/psy_text.pdf'})]

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnableMap

template = """Answer the question as based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
gemini = ChatGoogleGenerativeAI(model="gemini-pro", temperature = 0)

chain = RunnableMap({
    "context": lambda x: retriever.get_relevant_documents(x['question']),
    "question": lambda x: x['question']
}) | prompt | gemini

# %%
Markdown(chain.invoke({'question': "스트레스를 받을때"}).content)
# Out:
# 즉각 자리를 피하고, 한적한 곳을 걸으며 왜 화가 나는지, 무엇을 위해 화를 내는지, 다른 효과적인 방법이 없는지 집중해 보는 것
